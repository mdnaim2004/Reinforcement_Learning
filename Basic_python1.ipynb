# %% [markdown]
# ## First python code for ML
# ---
#
# - this is basic code for machine learning....
#
# - to star for the using python envirnment, jupiter notebook.
#
# - using conda envirnment....
#
#
#
# ---
# - input/output
# - variables
# - conditions
# - loop
# - functions
# ---

# %%
print("Hello,World\n")
print("this is my first journy of the mechine learning....")
print("this is my first code of pyhton programing for AI/ML.")
print("And this folder name of the Rainforcemrnt learning.")
# Out:
# Hello,World
#
# this is my first journy of the mechine learning....
# this is my first code of pyhton programing for AI/ML.
# And this folder name of the Rainforcemrnt learning.

# %% [markdown]
# ## Input / Output
#
# - it take  input from user
# - output to user...

# %%
input("Enter your name : ")
# Out:
# 'naim'

# %%
print("My name is  = Naim.")
# Out:
# My name is  = Naim.

# %% [markdown]
# ## Variavles.....
#
# ---
# - input function take a input and store the 'name' variable......
# - And out function using showing output which user take a input.....

# %%
name = input("Enter you name : ")

# %%
print("Your name is = ", name,"Islam.")
# Out:
# Your name is =  Naim  Islam.

# %% [markdown]
# ## Data type.
# ---
#
# - data type define how type of data,
#   in this data.....,
# - integer, floatig, dubble, string, character etc.....

# %%
num = 12345

# %%
print(num)
# Out:
# 12345

# %%
num + 10
# Out:
# 12355

# %%
num - 10
# Out:
# 12335

# %%
num * 10
# Out:
# 123450

# %%
num / 10
# Out:
# 1234.5

# %%
num = input()

# %%
num
# Out:
# '10000'

# %%
num + '10'
# Out:
# '1000010'

# %%
# how type of the function....
type(num)
# Out:
# str

# %%
num = 10
type(num)
# Out:
# int

# %% [markdown]
# - integer  ===>> 1234 etc
# - float    ===>> 3.1416  etc
# - string   ===>>  'abcdefghij'

# %%
integer = 12345
floating = 3.1416
string = 'abcdefgh'

# %%
type(integer)
# Out:
# int

# %%
type(floating)
# Out:
# float

# %%
type(string)
# Out:
# str

# %%
num = int(input())

# %%
type(num)
# Out:
# int

# %%
print(num)
# Out:
# 100000000

# %%
abcd = int(input())

# %%
abcd
# Out:
# 2000

# %%
int('12345')
# Out:
# 12345

# %%
float('1234567890')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 float('1234567890')
#
# TypeError: 'float' object is not callable
