# %% [markdown]
# ---
# # Pandas
# ---
# ---
# - Pandas serise is a typically of numpy
# ---

# %% [markdown]
# - Import numpy and pandas
# ---

# %%
import numpy as np
import pandas as pd

# %%
data = np.arange(5,10)
data
# Out:
# array([5, 6, 7, 8, 9])

# %% [markdown]
# ---
# - (Serise) --> This is a class of
# ---

# %%
pd_serise = pd.Series(data = data)
pd_serise
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %%
pd_serise[0]
# Out:
# np.int64(5)

# %%
pd_serise[2]
# Out:
# np.int64(7)

# %%
index = [ 'a', 'b', 'c', 'd', 'e']

# %%
pd_serise2 = pd.Series(data = data, index=index)

# %%
pd_serise2
# Out:
# a    5
# b    6
# c    7
# d    8
# e    9
# dtype: int64

# %%
pd_serise2[0]
# Out:
# /tmp/ipykernel_25519/3854447499.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pd_serise2[0]
# np.int64(5)

# %%
pd_serise2['a']
# Out:
# np.int64(5)

# %%
pd_serise.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
pd_serise.index = index
pd_serise
# Out:
# a    5
# b    6
# c    7
# d    8
# e    9
# dtype: int64

# %% [markdown]
# #### Using Dictionary

# %%
data = {
    'a' : 2,
    'b' : 457,
    'c' : 67
}
                # paramiter = argument.

pd_serise3 = pd.Series(data = data)

pd_serise3
# Out:
# a      2
# b    457
# c     67
# dtype: int64
