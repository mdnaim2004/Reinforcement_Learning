# %%
import numpy as np

# %%
import pandas as pd

# %%
data = np.random.rand(6,5)
data
# Out:
# array([[0.12580304, 0.44520964, 0.26204459, 0.44262349, 0.1369886 ],
#        [0.76857942, 0.42806027, 0.11176261, 0.54655251, 0.09755654],
#        [0.43093308, 0.3387988 , 0.23083862, 0.73045415, 0.48928709],
#        [0.4012619 , 0.41855359, 0.59461041, 0.58370774, 0.43950878],
#        [0.39000545, 0.94963844, 0.29254415, 0.37057946, 0.27677237],
#        [0.38326046, 0.41113986, 0.66033794, 0.53907169, 0.58862499]])

# %%
df = pd.DataFrame(data = data)
df
# Out:
#           0         1         2         3         4
# 0  0.125803  0.445210  0.262045  0.442623  0.136989
# 1  0.768579  0.428060  0.111763  0.546553  0.097557
# 2  0.430933  0.338799  0.230839  0.730454  0.489287
# 3  0.401262  0.418554  0.594610  0.583708  0.439509
# 4  0.390005  0.949638  0.292544  0.370579  0.276772
# 5  0.383260  0.411140  0.660338  0.539072  0.588625

# %%
df[0]
# Out:
# 0    0.125803
# 1    0.768579
# 2    0.430933
# 3    0.401262
# 4    0.390005
# 5    0.383260
# Name: 0, dtype: float64

# %%
type(df[0])
# Out:
# pandas.core.series.Series

# %%
type(df[1])
# Out:
# pandas.core.series.Series

# %%
df2 = pd.DataFrame(data = data, columns=)
