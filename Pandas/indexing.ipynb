# %%
groups = ['group1']*3 + ['group2']*3
inside_group = ['row1', 'row2', 'row3']*2
column = ['col1', 'col2']

tup = list(zip(groups, inside_group))

# %%
groups = ['group1']*3 + ['group2']*3
groups
# Out:
# ['group1', 'group1', 'group1', 'group2', 'group2', 'group2']

# %%
inside_group = ['row1', 'row2', 'row3']*2
inside_group
# Out:
# ['row1', 'row2', 'row3', 'row1', 'row2', 'row3']

# %%
column = ['col1', 'col2']
column
# Out:
# ['col1', 'col2']

# %%
tup
# Out:
# [('group1', 'row1'),
#  ('group1', 'row2'),
#  ('group1', 'row3'),
#  ('group2', 'row1'),
#  ('group2', 'row2'),
#  ('group2', 'row3')]

# %%
list(zip(groups, inside_group))
# Out:
# [('group1', 'row1'),
#  ('group1', 'row2'),
#  ('group1', 'row3'),
#  ('group2', 'row1'),
#  ('group2', 'row2'),
#  ('group2', 'row3')]
