# %%
print("Hello,World!")
# Out:
# Hello,World!

# %%
import pandas as pd
import numpy as np


data = np.random.rand(8,5)
df = pd.DataFrame(
    data = data,
    index = ['row1', 'row2','row3','row4','row5','row6','row7','row8'],
    columns = ['col1', 'col2', 'col3', 'col4', 'col5']
)

df
# Out:
#           col1      col2      col3      col4      col5
# row1  0.787477  0.932664  0.355048  0.940100  0.652640
# row2  0.416220  0.426106  0.238782  0.453836  0.222194
# row3  0.456218  0.786947  0.587352  0.045125  0.554526
# row4  0.849462  0.855931  0.200172  0.698310  0.771423
# row5  0.044896  0.462102  0.590367  0.499706  0.521784
# row6  0.516631  0.920580  0.128740  0.746070  0.846847
# row7  0.112568  0.967430  0.187497  0.907413  0.786767
# row8  0.594098  0.610505  0.012357  0.224151  0.938324
