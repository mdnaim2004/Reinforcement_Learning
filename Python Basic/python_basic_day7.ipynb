# %% [markdown]
# # Functions

# %%
print("Hello,World")
# Out:
# Hello,World

# %%
def add(num1, num2):
    addition = num1 + num2
    print("In the addition is = ", addition)
    return addition

# %%
ad = add(30, 40)
print("Out of the function is execute of : ",ad)
# Out:
# In the addition is =  70
# Out of the function is execute of :  70

# %%
def func():
    return func

# %%
a = func()
print(type(a))
# Out:
# <class 'function'>

# %%
import turtle
def draw_squre(side_length):
    for i in range(4):
        turtle.forward(side_length)
        turtle.left(90)

counter = 0

while(counter < 90):
    draw_squre(100)
    turtle.right(4)
    counter +=1

turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[17], line 10
#       7 counter = 0
#       9 while(counter < 90):
# ---> 10     draw_squre(100)
#      11     turtle.right(4)
#      12     counter +=1
#
# Cell In[17], line 4, in draw_squre(side_length)
#       2 def draw_squre(side_length):
#       3     for i in range(4):
# ----> 4         turtle.forward(side_length)
#       5         turtle.left(90)
#
# File <string>:5, in forward(distance)
#
# Terminator:

# %%
def myfunc(x):
    print("inside my function", x)
    x = 10
    print("inside my function", x)

# %%
x = 20
myfunc(x)
print(x)
# Out:
# inside my function 20
# inside my function 10
# 20

# %%
def mult(n1 = 0, n2 = 0):
    return n1 * n2

# %%
ans = mult(3,5)
print("The multiplication answer is = ",ans)
# Out:
# The multiplication answer is =  15

# %%
mult()
# Out:
# 0

# %%
def fun(n1,n2):
    ans = n1 ** n2

    if ans % 2 == 1:
        print("the number is odd")
    else:
        print("The number is even")

# %%
fun(2,3)
# Out:
# The number is even

# %%
fun(3,3)
# Out:
# the number is odd

# %%
def f(n):
    for i in range(n):
        if n%2 == 0:
            print("Hello,World")

# %%
f(6)
# Out:
# Hello,World
# Hello,World
# Hello,World
# Hello,World
# Hello,World
# Hello,World

# %% [markdown]
# # Break and Continiue Statement

# %%
# while(1):
#     # n = input("please enter your input (0 to exit): ")
#     n = 10
#     n = int(n)
#     if n==0:
#         break
#     print("squre of", n, "is", n*n)

# %% [markdown]
# # String

# %%
s = "Hello,World! wlecome to the world."

# %%
len(s)
# Out:
# 34

# %%
s.lstrip()
# Out:
# 'Hello,World! wlecome to the world.'

# %%
s.rstrip()
# Out:
# 'Hello,World! wlecome to the world.'

# %%
s.split()
# Out:
# ['Hello,World!', 'wlecome', 'to', 'the', 'world.']

# %%
s.count("l")
# Out:
# 5

# %% [markdown]
# - how many time have a character or string.....

# %%
s.count("e")
# Out:
# 4

# %% [markdown]
# # Zip and Enumerate
# ---
#
# ## Zip
#
# ---
#
# zip() is useful to combine multiple lists or other iterable element-wise.

# %%
name = ['naim', 'saim', 'rahim', 'karim']
marks = [91, 89, 87, 95]

for name, marks in zip(name, marks):
    print(f"{name} : {marks}")
# Out:
# naim : 91
# saim : 89
# rahim : 87
# karim : 95

# %%
name = ['naim', 'saim', 'rahim', 'karim']
marks = [91, 89, 87, 95,78, 95, 90]

for name, marks in zip(name, marks):
    print(f"{name} : {marks}")
# Out:
# naim : 91
# saim : 89
# rahim : 87
# karim : 95

# %%
name = ['naim', 'saim', 'rahim', 'karim','hafiz']
marks = [91, 89, 87]

for name, marks in zip(name, marks):
    print(f"{name} : {marks}")
# Out:
# naim : 91
# saim : 89
# rahim : 87

# %%
name = ['naim', 'saim', 'rahim', 'karim']
marks = [91, 89, 87, 95]

student_marks = dict(zip(name, marks))
print(student_marks)
# Out:
# {'naim': 91, 'saim': 89, 'rahim': 87, 'karim': 95}

# %%
name = ['naim', 'saim', 'rahim', 'karim','hafiz']
marks = [91, 89, 87]

student_marks = dict(zip(name, marks))
print(student_marks)
# Out:
# {'naim': 91, 'saim': 89, 'rahim': 87}

# %%
for idx, student in enumerate(name, start=1):
    print(f"{idx}. {student}")
# Out:
# 1. naim
# 2. saim
# 3. rahim
# 4. karim
# 5. hafiz

# %% [markdown]
# # Hashmap
#
#
# ## key value pairs

# %%
arr = [1,2,3,4,5,6,7,8,9]

# %%
arr[0]
# Out:
# 1

# %%
arr[1]
# Out:
# 2

# %%
arr[6]
# Out:
# 7

# %% [markdown]
# var_name = {key : value}

# %%
chagol = {100:'naim'}

# %%
chagol[100]
# Out:
# 'naim'

# %%
chagol = {100:'naim', "name" : "mdnaim2004"}

# %%
chagol['name']
# Out:
# 'mdnaim2004'

# %%
chagol.keys()
# Out:
# dict_keys([100, 'name'])

# %%
chagol.values()
# Out:
# dict_values(['naim', 'mdnaim2004'])

# %%
chagol.items()
# Out:
# dict_items([(100, 'naim'), ('name', 'mdnaim2004')])

# %% [markdown]
# ### Summary

# %% [markdown]
# - functions
# - dictionary
#     - key values pair
#     some functions
#     --------------
#     - keys()
#     - values()
#     - items()
