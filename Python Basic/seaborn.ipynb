# %%
"helloWorld!"
# Out:
# 'helloWorld!'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5,6,7,8,9])
plt.ylabel('some numbers')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([10,40,50,20,10,5,60,30], 'r')
plt.xlabel('naim')
plt.ylabel('anything')
plt.show()

# %%
x = np.arange(0, 20, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
plt.plot([1,29,3,4,56,65,3,2,50,6,8,5,53,27,78,50,45])
plt.xlabel('somthing buy')
plt.ylabel('something monthly spend')
plt.show()

# %%
x = ([10,20,30,10,20,30,5,0.8,9.7,90,45,3])
plt.plot(x)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/mdnaim/MyDesk/Reinforcement_Learning/Pandas/test.csv')

# %%
df
# Out:
#    Unnamed: 0  col1  col2    col3
# 0           0     9   433    sara
# 1           1     5   499  staeve
# 2           2     2   487  staeve
# 3           3     4   277    sara
# 4           4     9   403    sara
# 5           5     3   203    mike
# 6           6     2   379  staeve
# 7           7     2   345     bob
# 8           8     2   301     bob
# 9           9     4   260    sara

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     int64
#  1   col1        10 non-null     int64
#  2   col2        10 non-null     int64
#  3   col3        10 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 448.0+ bytes

# %%
df.head
# Out:
# <bound method NDFrame.head of    Unnamed: 0  col1  col2    col3
# 0           0     9   433    sara
# 1           1     5   499  staeve
# 2           2     2   487  staeve
# 3           3     4   277    sara
# 4           4     9   403    sara
# 5           5     3   203    mike
# 6           6     2   379  staeve
# 7           7     2   345     bob
# 8           8     2   301     bob
# 9           9     4   260    sara>

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of    Unnamed: 0  col1  col2    col3
# 0           0     9   433    sara
# 1           1     5   499  staeve
# 2           2     2   487  staeve
# 3           3     4   277    sara
# 4           4     9   403    sara
# 5           5     3   203    mike
# 6           6     2   379  staeve
# 7           7     2   345     bob
# 8           8     2   301     bob
# 9           9     4   260    sara>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = df

# %%
sns.histplot(
    data = data,
    x = 'col2', 
)
# Out:
# <Axes: xlabel='col2', ylabel='Count'>
