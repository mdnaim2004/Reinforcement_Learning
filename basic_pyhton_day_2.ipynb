# %% [markdown]
# ## Data Type...
# ---
#
# - x = 50   # integer
# - y = 3.1416    # float
# - z = 'hello,World'    # string
# - m = ["hello","World","explore", "the", "World"]     # list
# - n = ("hello","World","explore", "the", "World")      # tuple
#
# ---

# %% [markdown]
# #### 1.Numeric Datatype...
#
# ---
#
# - int ==>> its integer type of data, ex: 5, 7, 9, 1000, 1500 etc.
# - float ==>> its float type of data, ex: 3.1416, 9.7, 100.50 etc.
# - complex ==>> irs complex type of datatype, its two types of data
#
#             (real part) + (immaginary part)
#
#             ex: 4 + 3i, 2 + 9i

# %%
num = 5
print(type(num))

num1 = 3.14159
print(type(num1))

num2 = '4 + 3i' # bubt it cannot work this 4+3i its a complex number....
print(type(num2))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ### sequencial datatype
# ---
# - string ==>> srting type of data, ex: "Hello,World"
# - its type of all carrecter....
