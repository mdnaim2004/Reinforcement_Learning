# %%
print("hello,World!")
# Out:
# hello,World!

# %% [markdown]
# ### LOOP
#
#
# ##### - Syntax
#
# - for variable in itarable:

# %% [markdown]
# for i in iterable:
#
#         print(variable)

# %%
for variable in 'naim':
    print(variable)
# Out:
# n
# a
# i
# m
