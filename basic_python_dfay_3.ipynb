# %%
print("Hello,World explore the world!")
# Out:
# Hello,World explore the world!

# %% [markdown]
# ## Array/List

# %%
arr = [1, 2, 3, 4, 5]

# %%
arr
# Out:
# [1, 2, 3, 4, 5]

# %%
array = [10, 20, 30, 40, 50]
