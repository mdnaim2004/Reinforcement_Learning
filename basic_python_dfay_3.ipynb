# %%
print("Hello,World explore the world!")
# Out:
# Hello,World explore the world!

# %% [markdown]
# ## Array/List
#
# it declare the third bracket....

# %%
arr = [1, 2, 3, 4, 5]

# %%
arr
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## Array indexcing

# %% [markdown]
# alwayes should be start 0 index.....

# %%
array = [10, 20, 30, 40, 50]

# %%
array[0]
# Out:
# 10

# %%
array[4]
# Out:
# 50

# %% [markdown]
# replace the value of array index of 4th index....

# %%
array[4] = 60

# %% [markdown]
# it change

# %%
array[4]
# Out:
# 60

# %% [markdown]
# add sting with array element then it will be final array

# %%
array[3] = 'hello'

# %%
array[2] = 'hi'

# %%
array
# Out:
# [10, 20, 'hi', 'hello', 60]

# %%
arr = [100, 200, 400, 500, 600, 700, 800, 900]

# %%
print("Length of the array = ",len(arr))
# Out:
# Length of the array =  8
