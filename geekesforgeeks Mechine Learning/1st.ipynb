# %%
print("Hello,World")
# Out:
# Hello,World

# %%
for i in range(0,10):
    print("ABCD")
# Out:
# ABCD
# ABCD
# ABCD
# ABCD
# ABCD
# ABCD
# ABCD
# ABCD
# ABCD
# ABCD

# %%
a = ['geeks', 'for', 'geeks']

for indx in range(len(a)):
    print(a[indx])
# Out:
# geeks
# for
# geeks

# %%
n = 0
while(n < 10):
    n = n+1
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
x = 0
while x < 100:
    x+=2
print(x)
# Out:
# 100

# %%
def func():
    print("Welcome to GFG")

# %%
func()
# Out:
# Welcome to GFG

# %%
def oddeven(x):
    if(x%2 == 0):
        return "Even"
    else: return "Odd"

# %%
print(oddeven(14))
print(oddeven(7))
# Out:
# Even
# Odd

# %%
def f(y):
    if y % 3 == 0:
        print("divisable into 3")
    else : print("Not Divisiable!")

# %%
f(32)
# Out:
# Not Divisiable!
