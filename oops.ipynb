# %%
"hello,w0rld"
# Out:
# 'hello,w0rld'

# %%
class A:
    age = 10
    print(age)
obj = A()
# Out:
# 10

# %%
class A:
    def __init__(self):
        age = 10
        print(age)
obj = A()
# Out:
# 10

# %%
class A:
    def __init__(self):
        age = 10
        print(age)
obj = A()
obj2 = A()
# Out:
# 10
# 10

# %%
# if object hide
class A:
    def __init__(self):
        age = 10
        print(age)
#obj = A()

# %%
class A:
    age = 10
    "Learn coding....."
    print(age)

obj = A()
# Out:
# 10

# %%
class A:
    age = 10
    print(age)
obj = A()
print(obj.age)
print(A.age)
# Out:
# 10
# 10
# 10

# %%
class B:
    def __init__(self):
        a = 100
        b = 200
        print(a," ", b)

obj = B()
# Out:
# 100   200
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 8
#       5         print(a," ", b)
#       7 obj = B()
# ----> 8 print(obj.b)
#
# AttributeError: 'B' object has no attribute 'b'

# %%
class B:
    c = 500
print(B)
# Out:
# <class '__main__.B'>

# %%
class C:
    c = 1000
    print(c)
obj = C()
print(obj.c)
# Out:
# 1000
# 1000

# %%
class D:
    def __init__(self):
        sum = 500+100
        print(sum)
obj = D()
# Out:
# 600

# %%
class D:
    def __init__(self):
        sum = 500+100
        print(sum)
obj = D()
# Out:
# 600
